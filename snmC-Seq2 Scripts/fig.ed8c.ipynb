# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import pybedtools
import os

# %%
cluster_rename = pd.read_csv('PATH-TO-ANALYSIS/Human/integration-with-rna/integration_results/cytosplore.human.tsv',sep='\t')
cluster_rename = dict(zip(cluster_rename['DNAm_cluster_name'], cluster_rename['DNAm_cluster_label']))

# %%
sub20_df = pd.read_csv('Human_SubCluster_DMR_20+dms.tsv', sep='\t')

# %%
sub20_df.columns = sub20_df.columns.map(lambda x: x.replace('methylation_level_',''))

# %%
tmp = sub20_df[sub20_df.columns[4:]]
tmp.columns = tmp.columns.map(cluster_rename)
sns.clustermap(tmp, cmap='viridis')
plt.tight_layout()
# Out:
# /home/wtian/local/anaconda3/envs/cemba-mapping/lib/python3.7/site-packages/matplotlib/figure.py:2362: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   warnings.warn("This figure includes Axes that are not compatible "
